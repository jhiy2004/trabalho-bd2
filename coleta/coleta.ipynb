# %%
import pandas as pd

# %%
df = pd.concat(
    [pd.read_csv(f'datasets/part{i}.csv', sep=";", on_bad_lines='skip') for i in range(1, 6)]
)

# %%
df.to_parquet('../data/sc.parquet', engine='fastparquet')
